# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('linearRegression_coursework_113.csv')
dataset.head()
# Out:
#        a       b
# 0  77.96  128.03
# 1  65.68   95.52
# 2  82.85  133.97
# 3  87.44  126.26
# 4  65.25  115.66

# %%
plt.scatter(dataset.a, dataset.b, label='scatter')
plt.legend()
plt.show()

# %%
datasetGuess = pd.read_csv('guess.csv')
datasetGuess.head(10)
# Out:
#    x  Line1
# 0  0  34.80
# 1  1  36.05
# 2  2  37.30
# 3  3  38.55
# 4  4  39.80
# 5  5  41.05
# 6  6  42.30
# 7  7  43.55
# 8  8  44.80
# 9  9  46.05

# %%
plt.scatter(datasetGuess.x, datasetGuess.Line1,c='g', label='Line1')
plt.legend()

# %%
datasetGuess1 = pd.read_csv('guess1.csv')
datasetGuess1.head(10)
# Out:
#    x  Line2
# 0  0   34.5
# 1  1   35.7
# 2  2   36.9
# 3  3   38.1
# 4  4   39.3
# 5  5   40.5
# 6  6   41.7
# 7  7   42.9
# 8  8   44.1
# 9  9   45.3

# %%
plt.scatter(datasetGuess1.x, datasetGuess1.Line2, c='r',label='Line2')
plt.legend()

# %%
datasetGuess2 = pd.read_csv('guess2.csv')
datasetGuess2.head(10)
# Out:
#    x  Line3
# 0  0  34.70
# 1  1  35.97
# 2  2  37.24
# 3  3  38.51
# 4  4  39.78
# 5  5  41.05
# 6  6  42.32
# 7  7  43.59
# 8  8  44.86
# 9  9  46.13

# %%
plt.scatter(datasetGuess2.x, datasetGuess2.Line3, c='y',label='Line3')
plt.legend()

# %%
data_orginal = pd.read_csv('orginal.csv')
data_orginal.head(10)
# Out:
#    x  lineorginal
# 0  0        34.77
# 1  1        35.99
# 2  2        37.21
# 3  3        38.43
# 4  4        39.65
# 5  5        40.87
# 6  6        42.09
# 7  7        43.31
# 8  8        44.53
# 9  9        45.75

# %%
plt.scatter(data_orginal.x, data_orginal.lineorginal, c='BLACK', label='lineorginal')
plt.legend()

# %%
plt.scatter(dataset.a, dataset.b, label='scatter')
plt.plot(datasetGuess.x, datasetGuess.Line1, c='G', label='Line1')
plt.plot(datasetGuess1.x, datasetGuess1.Line2, c='R', label='Line2')
plt.plot(datasetGuess2.x, datasetGuess2.Line3, c='Y', label='Line3')
plt.plot(data_orginal.x, data_orginal.lineorginal, c='BlACK', label='lineorginal')
plt.legend()
plt.show()

# %%
plt.scatter(dataset.a, dataset.b, label='scatter')
plt.plot(datasetGuess.x, datasetGuess.Line1, c='G', label='Line1')
plt.legend()
plt.show()

# %%
plt.scatter(dataset.a, dataset.b, label='scatter')
plt.plot(datasetGuess1.x, datasetGuess1.Line2, c='R', label='Line2')
plt.legend()
plt.show()

# %%
plt.scatter(dataset.a, dataset.b, label='scatter')
plt.plot(datasetGuess2.x, datasetGuess2.Line3, c='Y', label='Line3')
plt.legend()
plt.show()

# %%
plt.scatter(dataset.a, dataset.b, label='scatter')
plt.plot(data_orginal.x, data_orginal.lineorginal, c='BlACK', label='Lineorginal')
plt.legend()
plt.show()

# %%
plt.plot(datasetGuess.x, datasetGuess.Line1, c='G', label='Line1')
plt.plot(datasetGuess1.x, datasetGuess1.Line2, c='R', label='Line2')
plt.plot(datasetGuess2.x, datasetGuess2.Line3, c='Y', label='Line3')
plt.plot(data_orginal.x, data_orginal.lineorginal, c='BlACK', label='lineorginal')
plt.legend()
plt.show()
